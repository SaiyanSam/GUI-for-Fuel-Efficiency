# %%
import pandas as pd
from tkinter import *
from PIL import ImageTk, Image
from tkinter import messagebox
import matplotlib.pyplot as plt

#here Comp_choice represent company id selected by user
global main

main=Tk()
main.config(background="white")
#geometry('widthxheight + xaxis +y axis)
main.geometry('378x200+480+180')

def start():
    #geometry('widthxheight + xaxis +y axis)
    main.geometry('378x350+480+125')
    panel.config(text=("Choose the company of your vehicle: \n"+"(You can scroll the list for options)"))
    
    # Global listbox for company of automobile
    global company
    company=Listbox(main,height=5,width=40)
    company.insert(0 , "Alfa Romeo")
    company.insert(1 , "Audi")
    company.insert(2 , "BMW")
    company.insert(3 , "Buick")
    company.insert(4 , "Chevrolet")
    company.insert(5 , "Dodge")
    company.insert(6 , "Isuzu")
    company.insert(7 , "Plymouth")
    company.insert(8 , "Pontiac")
    company.insert(9 , "Rolls-Royce")
    company.insert(10 , "Saab")
    company.insert(11 , "Saturn")
    company.insert(12 , "Subaru")
    company.insert(13 , "Tesla")
    company.insert(14 , "Toyota")
    company.insert(15 , "Volkswagen")
    company.insert(16 , "Volvo")
    company.grid(row=2,columnspan=2,pady=10)
    
    #disabling the proceed buttom till an item selected from list
    b2['state'] = 'disable'
    
    #Adding label and text field
    global L1,e1,c_id
    #here c_id represent id column of csv file
    L1=Label(main,bg="White",text="Enter id for vehicle : ")
    L1.grid(row=3,column=0,padx=10)
    
    #activating proceed button when clicked on listbox
    company.bind("<Button-1>", callback)

    c_id=StringVar()
    e1=Entry(main,textvariable=c_id,bd=5)
    e1.grid(row=3,column=1,padx=10)
    
    b2.config(text='Proceed',command=check1)
    b1.grid(row=4,column=1,padx=10)
    b2.grid(row=4,column=0,padx=10)
    
def callback(event):
    b2['state'] = 'normal'
    
def check1():
    #stores the selected list member index in form of tuple
    user_sel=company.curselection()
    
    #to check if no item is selected from listbox, means if tuple is empty
    if not user_sel:
        messagebox.showinfo("Attention!","Select Manufacturer from the list before you proceed.") 
    else:
        validate_field1()
        
def reset():
    #To reset the selection of fields for fresh input
    company.selection_clear(0 , END)
    c_id.set("")
    
def validate_field1():
    item=e1.get()
    if( item.isdigit() ):
        subm()
    else:
        messagebox.showinfo("Attention!","id column should contain integer values only.")
        c_id.set("")

def exit():
    ex=messagebox.askyesno("Exit?","Do you want to exit?")
    if(ex>0):
        main.destroy()  
    
def check():
    #to check if the id value belong to this company
    data = df[df['id']==i]
    
    #Now we calculate if there is any record in manufacturer database having id=user_input
    if(len(data.id.value_counts())==0):
        messagebox.showinfo("Attention!","Entered id does not match with selected Manufacter. Try again.")
        #To reset the selection of fields for fresh input
        reset()
    else:
        #To continue if the id and manufacturer matches
        cont()
    
def subm():  
    #geometry('widthxheight + xaxis +y axis)
    main.geometry('680x650+320+50')
    user_sel=company.curselection()
    
    # For storing name of company and comapny id
    global comp,Comp_choice
    # For storing logo of company
    global img
    # df is for retreiving company dataframe, df1 inherits the data for particular vehicle id
    global df,df1,i
    
    #get() function retrieve string data, so converting to int data
    i=c_id.get()
    i=int(i)
   
    if (user_sel[0]==0):
        comp="Alfa Romeo"
        img=ImageTk.PhotoImage(Image.open("C:\\CodersWorldV2\\Image gallery\\Alfa.png"))
        #retrieving car records for the company
        df=pd.read_csv('C:\\CodersWorldV2\\Sorted data Maker-wise\\Alfa.csv')
        Comp_choice=0
        check()
    elif (user_sel[0]==1):
        comp="Audi"
        img=ImageTk.PhotoImage(Image.open("C:\\CodersWorldV2\\Image gallery\\Audi.png"))
        #retrieving car records for the company
        df=pd.read_csv('C:\\CodersWorldV2\\Sorted data Maker-wise\\Audi.csv')
        Comp_choice=1
        check()
    elif (user_sel[0]==2):
        comp="BMW"
        img=ImageTk.PhotoImage(Image.open("C:\\CodersWorldV2\\Image gallery\\BMW.png"))
        #retrieving car records for the company
        df=pd.read_csv('C:\\CodersWorldV2\\Sorted data Maker-wise\\BMW.csv')
        Comp_choice=2
        check()
    elif (user_sel[0]==3):
        comp="Buick"
        img=ImageTk.PhotoImage(Image.open("C:\\CodersWorldV2\\Image gallery\\Buick.png"))
        #retrieving car records for the company
        df=pd.read_csv('C:\\CodersWorldV2\\Sorted data Maker-wise\\Buick.csv')
        Comp_choice=3
        check()
    elif (user_sel[0]==4):
        comp="Chevrolet"
        img=ImageTk.PhotoImage(Image.open("C:\\CodersWorldV2\\Image gallery\\Chevrolet.png"))
        #retrieving car records for the company
        df=pd.read_csv('C:\\CodersWorldV2\\Sorted data Maker-wise\\Chevrolet.csv')
        Comp_choice=4
        check()
    elif (user_sel[0]==5):
        comp="Dodge"
        img=ImageTk.PhotoImage(Image.open("C:\\CodersWorldV2\\Image gallery\\Dodge.png"))
        #retrieving car records for the company
        df=pd.read_csv('C:\\CodersWorldV2\\Sorted data Maker-wise\\Dodge.csv')
        Comp_choice=5
        check()
    elif (user_sel[0]==6):
        comp="Isuzu"
        img=ImageTk.PhotoImage(Image.open("C:\\CodersWorldV2\\Image gallery\\Isuzu.png"))
        #retrieving car records for the company
        df=pd.read_csv('C:\\CodersWorldV2\\Sorted data Maker-wise\\Isuzu.csv')
        Comp_choice=6
        check()
    elif (user_sel[0]==7):
        comp="Plymouth"
        img=ImageTk.PhotoImage(Image.open("C:\\CodersWorldV2\\Image gallery\\Plymouth.png"))
        #retrieving car records for the company
        df=pd.read_csv('C:\\CodersWorldV2\\Sorted data Maker-wise\\Plymouth.csv')
        Comp_choice=7
        check()
    elif (user_sel[0]==8):
        comp="Pontiac"
        img=ImageTk.PhotoImage(Image.open("C:\\CodersWorldV2\\Image gallery\\Pontiac.png"))
        #retrieving car records for the company
        df=pd.read_csv('C:\\CodersWorldV2\\Sorted data Maker-wise\\Pontiac.csv')
        Comp_choice=8
        check()
    elif (user_sel[0]==9):
        comp="Rolls-Royce"
        img=ImageTk.PhotoImage(Image.open("C:\\CodersWorldV2\\Image gallery\\Rolls-Royce.png"))
        #retrieving car records for the company
        df=pd.read_csv('C:\\CodersWorldV2\\Sorted data Maker-wise\\Rolls-Royce.csv')
        Comp_choice=9
        check()
    elif (user_sel[0]==10):
        comp="Saab"
        img=ImageTk.PhotoImage(Image.open("C:\\CodersWorldV2\\Image gallery\\Saab.png"))
        #retrieving car records for the company
        df=pd.read_csv('C:\\CodersWorldV2\\Sorted data Maker-wise\\Saab.csv')
        Comp_choice=10
        check()
    elif (user_sel[0]==11):
        comp="Saturn"
        img=ImageTk.PhotoImage(Image.open("C:\\CodersWorldV2\\Image gallery\\Saturn.png"))
        #retrieving car records for the company
        df=pd.read_csv('C:\\CodersWorldV2\\Sorted data Maker-wise\\Saturn.csv')
        Comp_choice=11
        check()
    elif (user_sel[0]==12):
        comp="Subaru"
        img=ImageTk.PhotoImage(Image.open("C:\\CodersWorldV2\\Image gallery\\Subaru.png"))
        #retrieving car records for the company
        df=pd.read_csv('C:\\CodersWorldV2\\Sorted data Maker-wise\\Subaru.csv')
        Comp_choice=12
        check()
    elif (user_sel[0]==13):
        comp="Tesla"
        img=ImageTk.PhotoImage(Image.open("C:\\CodersWorldV2\\Image gallery\\Tesla.png"))
        #retrieving car records for the company
        df=pd.read_csv('C:\\CodersWorldV2\\Sorted data Maker-wise\\Tesla.csv')
        Comp_choice=13
        check()
    elif (user_sel[0]==14):
        comp="Toyota"
        img=ImageTk.PhotoImage(Image.open("C:\\CodersWorldV2\\Image gallery\\Toyota.png"))
        #retrieving car records for the company
        df=pd.read_csv('C:\\CodersWorldV2\\Sorted data Maker-wise\\Toyota.csv')
        Comp_choice=14
        check()
    elif (user_sel[0]==15):
        comp="Volkswagen"
        img=ImageTk.PhotoImage(Image.open("C:\\CodersWorldV2\\Image gallery\\Volkswagen.png"))
        #retrieving car records for the company
        df=pd.read_csv('C:\\CodersWorldV2\\Sorted data Maker-wise\\Volkswagen.csv')
        Comp_choice=15
        check()
    else:
        comp="Volvo"
        img=ImageTk.PhotoImage(Image.open("C:\\CodersWorldV2\\Image gallery\\Volvo.png"))
        #retrieving car records for the company
        df=pd.read_csv('C:\\CodersWorldV2\\Sorted data Maker-wise\\Volvo.csv')
        Comp_choice=16
        check()
        
def cont(): 
    company.destroy()
    e1.destroy()
    
    #adding image to window
    panel.config(image=img)
    panel.image=img
    label1.grid(row=0,columnspan=2,ipadx=60)
    panel.grid(row=1,columnspan=2)
    
    df.set_index('id',inplace=True)
    global df1,label2,choice
    df1=df.loc[i]
    
    # storing car details
    global model,engine,alt,mil_city,mil_highway
    model=df1.model
    engine=df1.engId
    # atvType being stored in alt variable. Used for filtering data based on fuel
    alt=df1.atvType
    mil_city=df1.city08
    mil_highway=df1.highway08
    trans=df1.trany
    
    # using print on dataframe makes it a series
    L1.config(font=("Courier,25"),text=("The model name is :  "+model),bg='black',fg='lime green')
    L1.grid(row=2,columnspan=2,ipadx=20,ipady=10)
   
    label2=Label(bg='white',font=("Courier,20"))
    global R1,R2
    #Will pack these buttons later
    R1=Radiobutton(main,text="Option A",command=fuel_g,bg='black',fg='lime green',font=("Courier,15"))
    R2=Radiobutton(main,text="Option B",command=fuel_g,bg='black',fg='lime green',font=("Courier,15"))
    
    if(alt=='EV'):
        label2.config(text=("Enter current charge in vehicle : \n"+"(in percentage)"))  
        label2.grid(row=3,column=0,padx=20,pady=10)
        pass_(1)
    elif(alt=='Plug-in Hybrid'):
        label2.config(text=("Click on the choice of fuel : \n"+"(Since vehicle is plug-in hybrid)"))
        label2.grid(row=3,columnspan=2,padx=20,pady=10)
        
        # adding radio button to choose between electricity or gas
        R1.config(text="Regular Gas",command=fuel_g)
        R1.grid(row=4,column=0)
        R2.config(text="Electricity",command=fuel_e)
        R2.grid(row=4,column=1)
        
        b2.grid(row=5,column=0)
        b1.grid(row=5,column=1)
    elif(alt=='Hybrid'):
        label2.config(text=("Click on the choice of fuel : \n"+"(Since vehicle is hybrid type)"))
        label2.grid(row=3,columnspan=2,padx=20,pady=10)
        
        # adding radio button to choose between electricity or gas
        R1.config(text="Regular Fuel",command=fuel_r)
        R1.grid(row=4,column=0)
        R2.config(text="Premium Fuel",command=fuel_p)
        R2.grid(row=4,column=1)
        
        b2.grid(row=5,column=0)
        b1.grid(row=5,column=1)
    elif(alt=='CNG'):
        ##GGE is gas gallon equivalent used for measuring CNG
        label2.config(text=("Enter current CNG in vehicle : \n"+"(in GGE)"))
        label2.grid(row=3,column=0,padx=20,pady=10)
        pass_(4)
    elif(alt=='Bifuel (CNG)'):
        ##GGE is gas gallon equivalent used for measuring CNG
        label2.config(text=("Enter current CNG in vehicle : \n"+"(in GGE)"))
        label2.grid(row=3,column=0,padx=20,pady=10)
        pass_(4)
    else:
        label2.config(text=("Enter current fuel in vehicle : \n"+"(in gallons)"))
        label2.grid(row=3,column=0,padx=20,pady=10)
        pass_(2)
        
def fuel_r():
    label2.config(text=("Enter current Regular fuel in vehicle : \n"+"(in gallons)"))
    pass_(2)
    
def fuel_p():
    label2.config(text=("Enter current Premium fuel in vehicle : \n"+"(in gallons)"))
    pass_(3)
        
def fuel_g():
    label2.config(text=("Enter current fuel in vehicle : \n"+"(in gallons)"))
    pass_(2)
    
def fuel_e():
    label2.config(text=("Enter current charge in vehicle : \n"+"(in percentage)"))
    pass_(1)
    
def pass_(a):
    cat_=a
    R1.destroy()
    R2.destroy()
    final(cat_)
        
def final(a):
    #cateogry will be 1 for electricity as fuel, 2 for regular, 3 for premium. 4 for CNG(or bifuel CNG)
    global cateogry
    cateogry=a
    global cur_fuel,km
    cur_fuel=StringVar()
    
    global e2,label3,e3
    label2.grid(row=3,column=0,columnspan=1,padx=20,pady=10)
    e2=Entry(main,textvariable=cur_fuel,bd=5)
    e2.grid(row=3,column=1,padx=20,pady=10,ipadx=40,ipady=3)  

    label3=Label(padx=60,pady=20,bg="white",font=("Courier,20"))
    label3.config(text=("Enter average Distance you drive daily :\n"+"(in Miles)"))
    label3.grid(row=5,column=0)
    
    km=StringVar()
    e3=Entry(main,textvariable=km,bd=5)
    e3.grid(row=5,column=1,padx=20,pady=10,ipadx=40,ipady=3)
    
    global note
    note=Label(padx=60,pady=20,bg="white",font=("Courier,20"))
    note.config(text=("Adjust the slider to a point proportional to your Daily Driving habits :\n\n"+"[City]                                                                           [Highway]"))
    note.grid(row=6,columnspan=2)
    
    global slider
    slider=Scale(main,from_=0,to_=100,length=400,showvalue=0,resolution=2,orient=HORIZONTAL)
    slider.set(50)
    slider.grid(row=7,columnspan=2)
    
    b2.grid(row=8,column=0,padx=10)
    b1.grid(row=8,column=1,padx=10,ipadx=80)
     
    b2.config(text='Calculate Details For Car',command=validate_field2)
    
def validate_field2():
    item=e2.get()
    item1=e3.get()
    if( item.isdigit() and item1.isdigit() ):
        validate()
    else:
        messagebox.showinfo("Attention!","Input should be integer values only.")
        cur_fuel.set("")
        km.set("")
    
def validate():
    if(cateogry==1):
        s=int(e2.get())
        if(s>100 or s<0):
            messagebox.showinfo("Attention!","Value of charge can only lie between 0 and 100.")
        else:
            plotg()
    else:
        plotg()
              
def plotg():
    df = pd.read_csv('C:\\CodersWorldV2\\Sorted data Maker-wise\\plot.csv')
    if(Comp_choice==0 or Comp_choice==4 or Comp_choice==8 or Comp_choice==12):
        data=df[['Serial','Alfa Romeo','Chevrolet','Pontiac','Subaru']]   
    elif(Comp_choice==1 or Comp_choice==5 or Comp_choice==9 or Comp_choice==13):
        data=df[['Serial','Audi','Dodge','Tesla','Rolls-Royce']]
    elif(Comp_choice==2 or Comp_choice==6 or Comp_choice==10 or Comp_choice==14):
        data=df[['Serial','BMW','Isuzu','Saab','Toyota']]
    else:
        data=df[['Serial','Buick','Plymouth','Saturn','Volkswagen','Volvo']]
    data.drop(['Serial'], axis=1).plot.line(title='Chart for Fuel Cost',figsize=(15,5))
    plt.ylabel('Fuel Cost')
    plt.show()
    
    ask=messagebox.showinfo("Compiled successfully","The plot has been created on the window of Jupyter where you have executed the code")
    calc()
            
def calc():
    #storing current fuel entered in entry field
    j=int(e2.get())
    #storing daily km distance
    k=int(e3.get())
    #storing slider value
    l=int(slider.get())
    
    #calculating preference fraction
    perc_high=l
    perc_city=100-perc_high

    # saving all values before destroying main tkinter window
    cat=cateogry
    global charge,mil_c,mil_h
    charge=df1.charge240
    mil_c=df1.city08
    mil_h=df1.highway08
    alter=df1.atvType
    manufac=df1.make
    model=df1.model
    
    # destroying all current components
    slider.destroy()
    label1.destroy()
    panel.destroy()
    b1.destroy()
    b2.destroy()
    e2.destroy()
    e3.destroy()
    label2.destroy()
    label3.destroy()
    note.destroy()
    L1.destroy()
    
    #geometry('widthxheight + xaxis +y axis)
    main.geometry('700x660+300+0')
    
    global text2,text3,text4,text5,text6,text7,text8,text9,text10,text11,text12,text13
    text1=Label(main,padx=60,pady=20,bg="White")
    text2=Label(main,padx=60,pady=20,bg="White",font=("Courier,10"))
    text3=Label(main,padx=60,pady=20,bg="White",font=("Courier,10"))
    text4=Label(main,padx=60,pady=20,bg="White",font=("Courier,10"))
    text5=Label(main,padx=60,pady=20,bg="White",font=("Courier,10"))
    text6=Label(main,padx=60,pady=20,bg="White",font=("Courier,10"))
    text7=Label(main,padx=60,pady=20,bg="White",font=("Courier,10"))
    text8=Label(main,padx=60,pady=20,bg="White",font=("Courier,10"))
    text9=Label(main,padx=60,pady=20,bg="White",font=("Courier,10"))
    text10=Label(main,padx=60,pady=20,bg="White",font=("Courier,10"))
    text11=Label(main,padx=60,pady=20,bg="White",font=("Courier,10"))
    
    global city_range,high_range
    if(cat==1):
        if(charge==0):
            charge=10
        time_to_charge=((100-j)*charge)/100
    
        #calculating range for vehicle based on city and highway mileage
        city_range=mil_city*(j/100)
        high_range=mil_highway*(j/100)
    else:
        #calculating range for vehicle based on city and highway mileage
        city_range=j*mil_city
        high_range=j*mil_highway
    
    city_range=round(city_range,2)
    high_range=round(high_range,2)
    text1.config(font=("Courier,20"),text=(manufac+" : "+model),bg='black',fg='lime green')
    text1.grid(row=0,columnspan=2)
    
    # calculating annual and daily distance based on slider values 
    global dist_year_c,dist_year_h
    dist_day_c=(k*perc_city)/100
    dist_day_h=(k*perc_high)/100

    dist_year_c=365*dist_day_c
    dist_year_h=365*dist_day_h
    dist_year_c=round(dist_year_c,2)
    dist_year_h=round(dist_year_h,2)
    
    # calculating annual and daily fuel consumption
    global fuel_year_c,fuel_year_h,cons
    fuel_day_c=(k*perc_city)/(mil_c*100)
    fuel_day_h=(k*perc_high)/(mil_h*100)
    fuel_year_c=365*fuel_day_c
    fuel_year_h=365*fuel_day_h
    fuel_year_c=round(fuel_year_c,2)    
    fuel_year_h=round(fuel_year_h,2)
    cons=fuel_year_c+fuel_year_h
    cons=round(cons,2)
    
    # canvas is used to draw horizontal line
    canvas=Canvas(main,width=700,height=10)
    canvas.grid(row=1,columnspan=2)
    canvas.create_line(0,5,700,5,fill='black',width=3)
    
    text2.config(text=("Enter your choice for range :"))
    text2.grid(row=2,column=0)
    text3.config(text="")
    text3.grid(row=2,column=1,ipadx=38)
    choice1=Radiobutton(main,text="City",command=range_city,bg='black',fg='lime green',font=("Courier,15"))
    choice1.grid(row=3,column=0,pady=5)
    choice2=Radiobutton(main,text="Highway",command=range_high,bg='black',fg='lime green',font=("Courier,15"))
    choice2.grid(row=3,column=1,pady=5)
     
    # canvas is used to draw horizontal line
    canvas1=Canvas(main,width=700,height=10)
    canvas1.grid(row=4,columnspan=2)
    canvas1.create_line(0,5,700,5,fill='black',width=3)
        
    text4.config(text=("Enter your choice for Average Mileage : "))
    text4.grid(row=5,column=0)
    text5.config(text="")
    text5.grid(row=5,column=1,ipadx=38)
    choice3=Radiobutton(main,text="City",command=mil_city1,bg='black',fg='lime green',font=("Courier,15"))
    choice3.grid(row=6,column=0,pady=5)
    choice4=Radiobutton(main,text="Highway",command=mil_high,bg='black',fg='lime green',font=("Courier,15"))
    choice4.grid(row=6,column=1,pady=5)   
    
    # canvas is used to draw horizontal line
    canvas2=Canvas(main,width=700,height=10)
    canvas2.grid(row=7,columnspan=2)
    canvas2.create_line(0,5,700,5,fill='black',width=3)
    
    if(cat==1):
        text6.config(font=("Courier,10"),text="Hours left to charge completly : \n"+"(At stable 240V supply)")
        text6.grid(row=8,column=0)
        text7.config(font=("Courier,10"),text=time_to_charge,bg='black',fg='lime green')
        text7.grid(row=8,column=1,ipadx=38,padx=10)
    else:
        text6.config(font=("Courier,10"),text="Yearly fuel Consumption : \n"+"(In Gallons)")
        text6.grid(row=8,column=0)
        text7.config(font=("Courier,10"),text=cons,bg='black',fg='lime green')
        text7.grid(row=8,column=1,ipadx=38,padx=10) 

    text8.config(text=("Select for yearly consumption of fuel :"))
    text8.grid(row=9,column=0)
    text9.config(text="")
    text9.grid(row=9,column=1,ipadx=38)
    choice5=Radiobutton(main,text="City",command=yearly_city,bg='black',fg='lime green',font=("Courier,15"))
    choice5.grid(row=10,column=0,pady=5)
    choice6=Radiobutton(main,text="Highway",command=yearly_high,bg='black',fg='lime green',font=("Courier,15"))
    choice6.grid(row=10,column=1,pady=5)
    
    # canvas is used to draw horizontal line
    canvas3=Canvas(main,width=700,height=10)
    canvas3.grid(row=11,columnspan=2)
    canvas3.create_line(0,5,700,5,fill='black',width=3)
    
    text10.config(text=("Select for yearly Distance travelled :\n"+"(In Miles)"))
    text10.grid(row=12,column=0)
    text11.config(text="")
    text11.grid(row=12,column=1,ipadx=38)
    choice7=Radiobutton(main,text="City",command=yearly_trav_c,bg='black',fg='lime green',font=("Courier,15"))
    choice7.grid(row=13,column=0,pady=5)
    choice8=Radiobutton(main,text="Highway",command=yearly_trav_h,bg='black',fg='lime green',font=("Courier,15"))
    choice8.grid(row=13,column=1,pady=5)
    
def range_city():
    text2.config(text=("City range for Current Fuel level :\n"+"(in Miles)"))
    text2.grid(row=2,column=0)
    text3.config(text=city_range,bg='black',fg='lime green')
    text3.grid(row=2,column=1,ipadx=38,padx=10)
        
def range_high():
    text2.config(text=("Highway range for Current Fuel level :\n"+"(in Miles)"))
    text2.grid(row=2,column=0)
    text3.config(text=high_range,bg='black',fg='lime green')
    text3.grid(row=2,column=1,ipadx=38,padx=10)
    
def mil_city1():
    text4.config(text=("Average City Mileage :"))
    text4.grid(row=5,column=0)
    text5.config(text=mil_c,bg='black',fg='lime green')
    text5.grid(row=5,column=1,ipadx=38,padx=10)

def mil_high():
    text4.config(text=("Average Highway Mileage :"))
    text4.grid(row=5,column=0)
    text5.config(text=mil_h,bg='black',fg='lime green')
    text5.grid(row=5,column=1,ipadx=38,padx=10)

def yearly_city():
    text8.config(text="Yearly fuel Consumption on City : \n"+"(In Unit Of Fuel)")
    text8.grid(row=9,column=0)
    text9.config(text=fuel_year_c,bg='black',fg='lime green')
    text9.grid(row=9,column=1,ipadx=38,padx=10) 
    
def yearly_high():
    text8.config(text="Yearly fuel Consumption on Highway : \n"+"(In Unit Of Fuel)")
    text8.grid(row=9,column=0)
    text9.config(text=fuel_year_h,bg='black',fg='lime green')
    text9.grid(row=9,column=1,ipadx=38,padx=10) 
    
def yearly_trav_c():
    text10.config(text=("Yearly Distance travelled in City :\n"+"(in Miles)"))
    text10.grid(row=12,column=0)
    text11.config(text=dist_year_c,bg='black',fg='lime green')
    text11.grid(row=12,column=1,ipadx=38,padx=10)
    
def yearly_trav_h():
    text10.config(text=("Yearly Distance travelled on Highway :\n"+"(in Miles)"))
    text10.grid(row=12,column=0)
    text11.config(text=dist_year_h,bg='black',fg='lime green')
    text11.grid(row=12,column=1,ipadx=38,padx=10)
    
global label1,panel
label1=Label(padx=100,pady=20,bg='black',fg='lime green')
label1.config(font=("Courier,20"),text=("Fuel Efficiency Calculator"))
label1.grid(row=0,columnspan=2)

panel = Label(padx=60,pady=20,bg="white")
panel.config(text=(""))
panel.grid(row=1,columnspan=2)

global b1,b2
b1=Button(main,text='Exit',bg='black',fg='lime green',font=("Courier,15"),command=exit)
b1.grid(ipadx=65,ipady=15,pady=10,row=2,column=1)

b2=Button(main,text='Enter Details',bg='black',fg='lime green',font=("Courier,15"),command=start)
b2.grid(ipadx=45,ipady=15,pady=10,row=2,column=0)

main.mainloop()
